# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("Apple Dataset.csv")
data.head(10)
# Out:
#         DATE  Trend   rate (FEDs rate)      CPI  Core CPI   EPS($)  \
# 0   1/1/2010      1               0.05  2.62111    1.51234    0.31
# 1   2/1/2010      1               0.14  2.15134    1.34945    0.31
# 2   3/1/2010      1               0.14  2.28617    1.15921    0.31
# 3   4/1/2010      1               0.17  2.20677    0.96751    0.36
# 4   5/1/2010      1               0.20  2.00355    0.94014    0.36
# 5   6/1/2010      1               0.20  1.12156    0.95020    0.36
# 6   7/1/2010      1               0.17  1.34078    0.95775    0.44
# 7   8/1/2010      1               0.18  1.15018    0.91710    0.44
# 8   9/1/2010      1               0.19  1.11831    0.81439    0.44
# 9  10/1/2010      1               0.20  1.16670    0.60272    0.54
#
#      PE Ratio       Price
# 0       20.80  157.649994
# 1       20.80  174.610001
# 2       20.80  165.119995
# 3       19.76  174.779999
# 4       19.76  177.570007
# 5       19.76  165.300003
# 6       17.44  149.800003
# ...

# %%
sns.pairplot(data, diag_kind='kde')

# %% [markdown]
# y = np.array(data["Price"])
#
# x_list = ["Trend", " rate (FEDs rate)", "CPI", "Core CPI ","EPS($)","  PE Ratio"]
#
# print("Checking the correlation")
# for i in x_list:
#     x = np.array(data[i])
#     print("\n",i, np.corrcoef(x,y))

# %%
x = data[[" rate (FEDs rate)","Core CPI ","EPS($)"]]
y = np.array(data["Trend"])

data.head()
# Out:
#        DATE  Trend   rate (FEDs rate)      CPI  Core CPI   EPS($)    PE Ratio  \
# 0  1/1/2010      1               0.05  2.62111    1.51234    0.31       20.80
# 1  2/1/2010      1               0.14  2.15134    1.34945    0.31       20.80
# 2  3/1/2010      1               0.14  2.28617    1.15921    0.31       20.80
# 3  4/1/2010      1               0.17  2.20677    0.96751    0.36       19.76
# 4  5/1/2010      1               0.20  2.00355    0.94014    0.36       19.76
#
#         Price
# 0  157.649994
# 1  174.610001
# 2  165.119995
# 3  174.779999
# 4  177.570007

# %%
import sklearn
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state=1)

from sklearn.linear_model import LogisticRegression

# %%
log_model = LogisticRegression()

# %%
log_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
predictions = log_model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
confusion_matrix(y_test,predictions)
# Out:
# array([[ 0, 14],
#        [ 0, 31]], dtype=int64)

# %%
accuracy_score(y_test,predictions)
# Out:
# 0.6888888888888889

# %%
netflix_data = pd.read_csv("Netflix Dataset.csv")
netflix_data.head(5)
# Out:
#        Date  Trend   rate (FEDs rate)      CPI  Core CPI    EPS  PE Ratio  \
# 0  1/1/2010      1               0.05  2.62111    1.51234  0.28     27.68
# 1  2/1/2010      1               0.14  2.15134    1.34945  0.28     27.68
# 2  3/1/2010      1               0.14  2.28617    1.15921  0.28     27.68
# 3  4/1/2010      1               0.17  2.20677    0.96751  0.32     33.37
# 4  5/1/2010      1               0.20  2.00355    0.94014  0.32     33.37
#
#    Stock Price
# 0         7.87
# 1         7.87
# 2         7.87
# 3        10.53
# 4        10.53

# %%
sns.pairplot(netflix_data, diag_kind="kde")
